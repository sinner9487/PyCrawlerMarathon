# %%
import requests 
url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = bs(r.text, "html5lib")

for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_="date").text, d.find_all('a')[-1].text)
# Out:
# 2020/07/24 17:20 溫柔夫結婚1年變臉！「一家都是惡魔」長腿人妻不堪地獄生活…絕望跳樓求生
# 2020/07/24 17:19 CBA／梅奧轟26分9籃板　領遼寧37分大勝狂取8連勝
# 2020/07/24 17:18 哈士奇露牙狠吼阿金：爸拔別攔我！　落地秒變「乖乖牌」笑翻6千人
# 2020/07/24 17:18 《通靈少女》劉柏君被罵是韓粉！　傻眼：我到底做了什麼
# 2020/07/24 17:17 中職／林哲瑄二軍用實戰調整　很期待張進德加入
# 2020/07/24 17:16 中山資管砸100萬獎助金攬才　今年入學新生每人獲2萬元
# 2020/07/24 17:16 張柏芝挨告！前經紀人控「拿了錢沒拍片」　公司要她償還4900萬
# 2020/07/24 17:13 呼應美國務卿蓬佩奧　外交部：感謝美國政府不斷為台灣仗義執言
# 2020/07/24 17:12 中職／富邦傷兵歸隊　蔣智賢最快明天上一軍
# 2020/07/24 17:12 嫌兒太吵...22歲父拿毛巾塞「出生82天」嬰嘴內致悶死！　辯：幫擦口水
# 2020/07/24 17:11 霍華德糗被「巨神兵」站著連搧2鍋　兩人都忍不住笑了
# 2020/07/24 17:08 【奧斯塔羅】分手後想復合...前任目前有新對象了嗎？
# 2020/07/24 17:05 論文設「永不公開」要有證明　教育部：校方若未落實將停招、沒收補助款
# 2020/07/24 17:05 出門上班不到1小時　狗奴收到「家裡下雪照」傻眼：清蒸紅燒？
# 2020/07/24 17:04 中職／邦威開始牛棚練投　最快八月初上一軍
# 2020/07/24 17:03 快訊／下班課注意！雷雨開炸「6縣市大雨特報」　防雷擊強陣風
# 2020/07/24 17:02 女主角難當！大元被狠抓胸部…下秒「跌進爛泥中」苦笑：還好我不怕髒
# 2020/07/24 17:02 善耕365／BiG行動夢想家高規學習營　助孩童登夢想舞台秀自信
# 2020/07/24 17:01 張本智和曾因疫情受打擊　想東奧奪金「痛苦時努力才能達成目標」
# 2020/07/24 17:00 2020亞洲生技大展　成大展現生醫技術成果與能量表現亮眼
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time

# %%
url = "https://www.ettoday.net/news/news-list.htm"

browser = webdriver.Chrome(executable_path= '/Users/sean/Desktop/GitHub/chromedriver')
browser.get(url)
#browser.close()

# %%
for i in range(50):
    time.sleep(1.5)
    browser.execute_script("window.scrollTo(0, 1000000);")

# %%
c = browser.page_source

soup = bs(c)

for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_="date").text, d.find_all('a')[-1].text)
# Out:
# 2020/07/24 17:20 溫柔夫結婚1年變臉！「一家都是惡魔」長腿人妻不堪地獄生活…絕望跳樓求生
# 2020/07/24 17:19 CBA／梅奧轟26分9籃板　領遼寧37分大勝狂取8連勝
# 2020/07/24 17:18 哈士奇露牙狠吼阿金：爸拔別攔我！　落地秒變「乖乖牌」笑翻6千人
# 2020/07/24 17:18 《通靈少女》劉柏君被罵是韓粉！　傻眼：我到底做了什麼
# 2020/07/24 17:17 中職／林哲瑄二軍用實戰調整　很期待張進德加入
# 2020/07/24 17:16 中山資管砸100萬獎助金攬才　今年入學新生每人獲2萬元
# 2020/07/24 17:16 張柏芝挨告！前經紀人控「拿了錢沒拍片」　公司要她償還4900萬
# 2020/07/24 17:13 呼應美國務卿蓬佩奧　外交部：感謝美國政府不斷為台灣仗義執言
# 2020/07/24 17:12 中職／富邦傷兵歸隊　蔣智賢最快明天上一軍
# 2020/07/24 17:12 嫌兒太吵...22歲父拿毛巾塞「出生82天」嬰嘴內致悶死！　辯：幫擦口水
# 2020/07/24 17:11 霍華德糗被「巨神兵」站著連搧2鍋　兩人都忍不住笑了
# 2020/07/24 17:08 【奧斯塔羅】分手後想復合...前任目前有新對象了嗎？
# 2020/07/24 17:05 論文設「永不公開」要有證明　教育部：校方若未落實將停招、沒收補助款
# 2020/07/24 17:05 出門上班不到1小時　狗奴收到「家裡下雪照」傻眼：清蒸紅燒？
# 2020/07/24 17:04 中職／邦威開始牛棚練投　最快八月初上一軍
# 2020/07/24 17:03 快訊／下班課注意！雷雨開炸「6縣市大雨特報」　防雷擊強陣風
# 2020/07/24 17:02 女主角難當！大元被狠抓胸部…下秒「跌進爛泥中」苦笑：還好我不怕髒
# 2020/07/24 17:02 善耕365／BiG行動夢想家高規學習營　助孩童登夢想舞台秀自信
# 2020/07/24 17:01 張本智和曾因疫情受打擊　想東奧奪金「痛苦時努力才能達成目標」
# 2020/07/24 17:00 2020亞洲生技大展　成大展現生醫技術成果與能量表現亮眼
# ...

# %%
#取出今天所有的新聞
#取出現在時間兩小時內的新聞
#根據範例，取出三天前下午三點到五點的新聞

# %%
import pandas as pd
columns = ['date', 'tag', 'text']
table = []

for d in soup.find(class_ = 'part_list_2').find_all('h3'):
    table.append([d.find('span').text, d.find('em').text, d.find('a').text])
    
df = pd.DataFrame(table, columns=columns)
df
# Out:
#                  date   tag                                 text
# 0    2020/07/24 17:20    大陸  溫柔夫結婚1年變臉！「一家都是惡魔」長腿人妻不堪地獄生活…絕望跳樓求生
# 1    2020/07/24 17:19    體育          CBA／梅奧轟26分9籃板　領遼寧37分大勝狂取8連勝
# 2    2020/07/24 17:18  寵物動物      哈士奇露牙狠吼阿金：爸拔別攔我！　落地秒變「乖乖牌」笑翻6千人
# 3    2020/07/24 17:18    影劇           《通靈少女》劉柏君被罵是韓粉！　傻眼：我到底做了什麼
# 4    2020/07/24 17:17    體育               中職／林哲瑄二軍用實戰調整　很期待張進德加入
# ..                ...   ...                                  ...
# 595  2020/07/23 21:48    影劇  《神偷奶爸》10週年…小小兵10冷知識曝！　他們平均身高只有105CM
# 596  2020/07/23 21:42    政治           私菸案被監院糾正　外交部：買免稅品屬個人行為無從介入
# 597  2020/07/23 21:38    旅遊    上山就不想下來！梯田式「無邊際山泉泳池」眺望夕陽　台南望山放空之旅
# 598  2020/07/23 21:35    國際         餵鹿吃胡蘿蔔！　一家人5分鐘後「聽一聲槍響」震驚：牠死了
# 599  2020/07/23 21:35   房產雲             花大錢買預售屋！裝潢好竟成建商樣品屋…地板全鞋印
#
# [600 rows x 3 columns]

# %%
import re
df[df.date.str.contains("2020/07/24*")]

#df_date.filter(regex="2020/07/24*", axis=0)
# Out:
#                  date   tag                                 text
# 0    2020/07/24 17:20    大陸  溫柔夫結婚1年變臉！「一家都是惡魔」長腿人妻不堪地獄生活…絕望跳樓求生
# 1    2020/07/24 17:19    體育          CBA／梅奧轟26分9籃板　領遼寧37分大勝狂取8連勝
# 2    2020/07/24 17:18  寵物動物      哈士奇露牙狠吼阿金：爸拔別攔我！　落地秒變「乖乖牌」笑翻6千人
# 3    2020/07/24 17:18    影劇           《通靈少女》劉柏君被罵是韓粉！　傻眼：我到底做了什麼
# 4    2020/07/24 17:17    體育               中職／林哲瑄二軍用實戰調整　很期待張進德加入
# ..                ...   ...                                  ...
# 595  2020/07/23 21:48    影劇  《神偷奶爸》10週年…小小兵10冷知識曝！　他們平均身高只有105CM
# 596  2020/07/23 21:42    政治           私菸案被監院糾正　外交部：買免稅品屬個人行為無從介入
# 597  2020/07/23 21:38    旅遊    上山就不想下來！梯田式「無邊際山泉泳池」眺望夕陽　台南望山放空之旅
# 598  2020/07/23 21:35    國際         餵鹿吃胡蘿蔔！　一家人5分鐘後「聽一聲槍響」震驚：牠死了
# 599  2020/07/23 21:35   房產雲             花大錢買預售屋！裝潢好竟成建商樣品屋…地板全鞋印
#
# [600 rows x 3 columns]

# %%
today_news = []
if
